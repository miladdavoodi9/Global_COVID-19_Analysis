# %%
# 1. import Flask
from flask import Flask, jsonify
from flask_sqlalchemy import SQLAlchemy

import pandas as pd
import numpy as np 
import sqlalchemy

from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func
from dateutil.relativedelta import relativedelta
import datetime as dt

# Auxiliary functions
def recovered(con, ded):
    try:
        return(con - ded)
    except TypeError:
        return(0)

def get_rate(input_value, conf):
    try:
        return(input_value / conf)
    except (ZeroDivisionError, TypeError):
        return(0)

engine = create_engine("sqlite:///COVID19_vs_H1N1.sqlite")
conn = engine.connect()

#reflect and exisiting database into a new model
Base = automap_base()

#reflect the tables
Base.prepare(engine, reflect=True)

#Save reference to the table
Country = Base.classes.country
Covid = Base.classes.covid
H1N1 = Base.classes.h1n1
Global_Covid = Base.classes.global_covid_data
Global_H1N1 = Base.classes.global_h1n1_data
# Connect, query, and close session
session = Session(engine)
results = session.query(
    Covid.Country, 
    Covid.Province,
    Covid.Date,
    Covid.Confirmed, 
    Covid.Deaths, 
    Covid.Recovered
    ).all()
session.close()

key_list = []
val_list = []

confirmed_list = []
recovered_list = []
deaths_list = []

for country, province, date, confirmed, deaths, recovered in results:
    key_list.append(country)

    temp_dict = {}
    temp_dict["Province"] = province
    temp_dict["Date"] = date.strftime('%Y-%m-%d')
    temp_dict["Confirmed"] = confirmed
    temp_dict["Deaths"] = deaths
    temp_dict["Recovered"] = recovered
    temp_dict["Recovery_Rate"] = get_rate(recovered, confirmed)
    temp_dict["Death_Rate"] = get_rate(deaths, confirmed)
    val_list.append(temp_dict)
    
    confirmed_list.append(confirmed)
    
    
confirmed_array = pd.Series(confirmed_list)
confirmed_percent_change = confirmed_array.pct_change()
confirmed_percent_change_list = confirmed_percent_change.tolist()


# print(confirmed_percent_change)
covid_dict = dict(zip(key_list, zip(val_list, confirmed_percent_change_list)))
covid_dict
# Out:
# {'Mainland China': ({'Province': 'Zhejiang',
#    'Date': '2020-04-02',
#    'Confirmed': 1258.0,
#    'Deaths': 1.0,
#    'Recovered': 1228.0,
#    'Recovery_Rate': 0.9761526232114467,
#    'Death_Rate': 0.000794912559618442},
#   5.8743169398907105),
#  'Hong Kong': ({'Province': 'Hong Kong',
#    'Date': '2020-04-02',
#    'Confirmed': 802.0,
#    'Deaths': 4.0,
#    'Recovered': 147.0,
#    'Recovery_Rate': 0.18329177057356608,
#    'Death_Rate': 0.004987531172069825},
#   0.048366013071895475),
#  'Macau': ({'Province': 'Macau',
#    'Date': '2020-04-02',
#    'Confirmed': 41.0,
#    'Deaths': 0.0,
#    'Recovered': 10.0,
#    'Recovery_Rate': 0.24390243902439024,
#    'Death_Rate': 0.0},
#   0.0),
#  'Taiwan': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 339.0,
#    'Deaths': 5.0,
#    'Recovered': 45.0,
#    'Recovery_Rate': 0.13274336283185842,
#    'Death_Rate': 0.014749262536873156},
#   0.03039513677811545),
#  'US': ({'Province': 'Wyoming',
#    'Date': '2020-04-02',
#    'Confirmed': 150.0,
#    'Deaths': 0.0,
#    'Recovered': 0.0,
#    'Recovery_Rate': 0.0,
#    'Death_Rate': 0.0},
#   -0.914187643020595),
#  'Japan': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 2495.0,
#    'Deaths': 62.0,
#    'Recovered': 472.0,
#    'Recovery_Rate': 0.18917835671342687,
#    'Death_Rate': 0.024849699398797595},
#   0.1455463728191),
#  'Thailand': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 1875.0,
#    'Deaths': 15.0,
#    'Recovered': 505.0,
#    'Recovery_Rate': 0.2693333333333333,
#    'Death_Rate': 0.008},
#   0.05872388481084134),
#  'South Korea': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 9976.0,
#    'Deaths': 169.0,
#    'Recovered': 5828.0,
#    'Recovery_Rate': 0.5842020850040096,
#    'Death_Rate': 0.016940657578187652},
#   0.009001719429553967),
#  'Singapore': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 1049.0,
#    'Deaths': 4.0,
#    'Recovered': 266.0,
#    'Recovery_Rate': 0.25357483317445184,
#    'Death_Rate': 0.0038131553860819827},
#   0.04899999999999993),
#  'Philippines': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 2633.0,
#    'Deaths': 107.0,
#    'Recovered': 51.0,
#    'Recovery_Rate': 0.019369540448157994,
#    'Death_Rate': 0.04063805545005697},
#   0.13933362180874087),
#  'Malaysia': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 3116.0,
#    'Deaths': 50.0,
#    'Recovered': 767.0,
#    'Recovery_Rate': 0.24614890885750962,
#    'Death_Rate': 0.016046213093709884},
#   0.07152682255845932),
#  'Vietnam': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 233.0,
#    'Deaths': 0.0,
#    'Recovered': 75.0,
#    'Recovery_Rate': 0.3218884120171674,
#    'Death_Rate': 0.0},
#   0.0688073394495412),
#  'Australia': ({'Province': 'Western Australia',
#    'Date': '2020-04-02',
#    'Confirmed': 400.0,
#    'Deaths': 2.0,
#    'Recovered': 64.0,
#    'Recovery_Rate': 0.16,
#    'Death_Rate': 0.005},
#   -0.6138996138996139),
#  'Mexico': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 1378.0,
#    'Deaths': 37.0,
#    'Recovered': 35.0,
#    'Recovery_Rate': 0.02539912917271408,
#    'Death_Rate': 0.026850507982583455},
#   0.13415637860082308),
#  'Brazil': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 8044.0,
#    'Deaths': 324.0,
#    'Recovered': 127.0,
#    'Recovery_Rate': 0.015788165091994034,
#    'Death_Rate': 0.04027846842366982},
#   0.17671152720889416),
#  'Colombia': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 1161.0,
#    'Deaths': 19.0,
#    'Recovered': 55.0,
#    'Recovery_Rate': 0.047372954349698536,
#    'Death_Rate': 0.01636520241171404},
#   0.09014084507042264),
#  'France': ({'Province': 'St Martin',
#    'Date': '2020-04-02',
#    'Confirmed': 22.0,
#    'Deaths': 1.0,
#    'Recovered': 2.0,
#    'Recovery_Rate': 0.09090909090909091,
#    'Death_Rate': 0.045454545454545456},
#   2.6666666666666665),
#  'Nepal': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 6.0,
#    'Deaths': 0.0,
#    'Recovered': 1.0,
#    'Recovery_Rate': 0.16666666666666666,
#    'Death_Rate': 0.0},
#   0.19999999999999996),
#  'Canada': ({'Province': 'Yukon',
#    'Date': '2020-04-02',
#    'Confirmed': 6.0,
#    'Deaths': 0.0,
#    'Recovered': 0.0,
#    'Recovery_Rate': 0.0,
#    'Death_Rate': 0.0},
#   -0.970873786407767),
#  'Cambodia': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 110.0,
#    'Deaths': 0.0,
#    'Recovered': 34.0,
#    'Recovery_Rate': 0.3090909090909091,
#    'Death_Rate': 0.0},
#   0.00917431192660545),
#  'Sri Lanka': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 151.0,
#    'Deaths': 4.0,
#    'Recovered': 21.0,
#    'Recovery_Rate': 0.1390728476821192,
#    'Death_Rate': 0.026490066225165563},
#   0.03424657534246567),
#  'Ivory Coast': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 194.0,
#    'Deaths': 1.0,
#    'Recovered': 15.0,
#    'Recovery_Rate': 0.07731958762886598,
#    'Death_Rate': 0.005154639175257732},
#   0.021052631578947434),
#  'Germany': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 84794.0,
#    'Deaths': 1107.0,
#    'Recovered': 22440.0,
#    'Recovery_Rate': 0.2646413661343963,
#    'Death_Rate': 0.01305516899780645},
#   0.08888945962605299),
#  'Finland': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 1518.0,
#    'Deaths': 19.0,
#    'Recovered': 300.0,
#    'Recovery_Rate': 0.1976284584980237,
#    'Death_Rate': 0.012516469038208168},
#   0.049792531120331995),
#  'United Arab Emirates': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 1024.0,
#    'Deaths': 8.0,
#    'Recovered': 96.0,
#    'Recovery_Rate': 0.09375,
#    'Death_Rate': 0.0078125},
#   0.25798525798525795),
#  'India': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 2543.0,
#    'Deaths': 72.0,
#    'Recovered': 191.0,
#    'Recovery_Rate': 0.07510813999213527,
#    'Death_Rate': 0.028313016122689737},
#   0.2727727727727727),
#  'Italy': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 115242.0,
#    'Deaths': 13915.0,
#    'Recovered': 18278.0,
#    'Recovery_Rate': 0.158605369570122,
#    'Death_Rate': 0.12074590860970827},
#   0.04221607249443804),
#  'UK': ({'Province': 'Turks and Caicos Islands',
#    'Date': '2020-04-02',
#    'Confirmed': 5.0,
#    'Deaths': 0.0,
#    'Recovered': 0.0,
#    'Recovery_Rate': 0.0,
#    'Death_Rate': 0.0},
#   0.0),
#  'Russia': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 3548.0,
#    'Deaths': 30.0,
#    'Recovered': 235.0,
#    'Recovery_Rate': 0.06623449830890643,
#    'Death_Rate': 0.008455467869222097},
#   0.27763773856679874),
#  'Sweden': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 5568.0,
#    'Deaths': 308.0,
#    'Recovered': 103.0,
#    'Recovery_Rate': 0.018498563218390805,
#    'Death_Rate': 0.05531609195402299},
#   0.1255306246209824),
#  'Spain': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 112065.0,
#    'Deaths': 10348.0,
#    'Recovered': 26743.0,
#    'Recovery_Rate': 0.23863829027796368,
#    'Death_Rate': 0.09233926738946148},
#   0.0763268599089495),
#  'Belgium': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 15348.0,
#    'Deaths': 1011.0,
#    'Recovered': 2495.0,
#    'Recovery_Rate': 0.16256189731561116,
#    'Death_Rate': 0.06587177482408131},
#   0.099112002291607),
#  'Others': ({'Province': 'Diamond Princess cruise ship',
#    'Date': '2020-03-23',
#    'Confirmed': 712.0,
#    'Deaths': 8.0,
#    'Recovered': 567.0,
#    'Recovery_Rate': 0.7963483146067416,
#    'Death_Rate': 0.011235955056179775},
#   0.0),
#  'Egypt': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 865.0,
#    'Deaths': 58.0,
#    'Recovered': 201.0,
#    'Recovery_Rate': 0.2323699421965318,
#    'Death_Rate': 0.06705202312138728},
#   0.11039794608472397),
#  'Iran': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 50468.0,
#    'Deaths': 3160.0,
#    'Recovered': 16711.0,
#    'Recovery_Rate': 0.33112071015296823,
#    'Death_Rate': 0.06261393358167552},
#   0.06040804319963011),
#  'Israel': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 6857.0,
#    'Deaths': 36.0,
#    'Recovered': 338.0,
#    'Recovery_Rate': 0.04929269359778329,
#    'Death_Rate': 0.005250109377278694},
#   0.12557452396585678),
#  'Lebanon': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 494.0,
#    'Deaths': 16.0,
#    'Recovered': 46.0,
#    'Recovery_Rate': 0.0931174089068826,
#    'Death_Rate': 0.032388663967611336},
#   0.03131524008350728),
#  'Iraq': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 772.0,
#    'Deaths': 54.0,
#    'Recovered': 202.0,
#    'Recovery_Rate': 0.2616580310880829,
#    'Death_Rate': 0.06994818652849741},
#   0.06043956043956045),
#  'Oman': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 231.0,
#    'Deaths': 1.0,
#    'Recovered': 57.0,
#    'Recovery_Rate': 0.24675324675324675,
#    'Death_Rate': 0.004329004329004329},
#   0.10000000000000009),
#  'Afghanistan': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 273.0,
#    'Deaths': 6.0,
#    'Recovered': 10.0,
#    'Recovery_Rate': 0.03663003663003663,
#    'Death_Rate': 0.02197802197802198},
#   0.1518987341772151),
#  'Bahrain': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 643.0,
#    'Deaths': 4.0,
#    'Recovered': 381.0,
#    'Recovery_Rate': 0.5925349922239502,
#    'Death_Rate': 0.006220839813374806},
#   0.1300527240773286),
#  'Kuwait': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 342.0,
#    'Deaths': 0.0,
#    'Recovered': 81.0,
#    'Recovery_Rate': 0.23684210526315788,
#    'Death_Rate': 0.0},
#   0.07886435331230279),
#  'Austria': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 11129.0,
#    'Deaths': 158.0,
#    'Recovered': 1749.0,
#    'Recovery_Rate': 0.15715697726660077,
#    'Death_Rate': 0.014197142600413335},
#   0.03902530109233493),
#  'Algeria': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 986.0,
#    'Deaths': 86.0,
#    'Recovered': 61.0,
#    'Recovery_Rate': 0.061866125760649086,
#    'Death_Rate': 0.0872210953346856},
#   0.16410861865407322),
#  'Croatia': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 1011.0,
#    'Deaths': 7.0,
#    'Recovered': 88.0,
#    'Recovery_Rate': 0.08704253214638971,
#    'Death_Rate': 0.006923837784371909},
#   0.049844236760124616),
#  'Switzerland': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 18827.0,
#    'Deaths': 536.0,
#    'Recovered': 4013.0,
#    'Recovery_Rate': 0.21315132522441174,
#    'Death_Rate': 0.028469750889679714},
#   0.05960153084196307),
#  'Pakistan': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 2421.0,
#    'Deaths': 34.0,
#    'Recovered': 125.0,
#    'Recovery_Rate': 0.05163155720776538,
#    'Death_Rate': 0.014043783560512184},
#   0.14305949008498575),
#  'Georgia': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 134.0,
#    'Deaths': 0.0,
#    'Recovered': 26.0,
#    'Recovery_Rate': 0.19402985074626866,
#    'Death_Rate': 0.0},
#   0.14529914529914523),
#  'Greece': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 1544.0,
#    'Deaths': 53.0,
#    'Recovered': 61.0,
#    'Recovery_Rate': 0.03950777202072539,
#    'Death_Rate': 0.03432642487046632},
#   0.09116607773851593),
#  'North Macedonia': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 384.0,
#    'Deaths': 11.0,
#    'Recovered': 17.0,
#    'Recovery_Rate': 0.044270833333333336,
#    'Death_Rate': 0.028645833333333332},
#   0.0847457627118644),
#  'Norway': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 5147.0,
#    'Deaths': 50.0,
#    'Recovered': 32.0,
#    'Recovery_Rate': 0.006217213911016126,
#    'Death_Rate': 0.009714396735962697},
#   0.058400164507505625),
#  'Romania': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 2738.0,
#    'Deaths': 115.0,
#    'Recovered': 267.0,
#    'Recovery_Rate': 0.09751643535427319,
#    'Death_Rate': 0.04200146092037984},
#   0.11300813008130084),
#  'Denmark': ({'Province': 'Greenland',
#    'Date': '2020-04-02',
#    'Confirmed': 10.0,
#    'Deaths': 0.0,
#    'Recovered': 2.0,
#    'Recovery_Rate': 0.2,
#    'Death_Rate': 0.0},
#   -0.943502824858757),
#  'Estonia': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 858.0,
#    'Deaths': 11.0,
#    'Recovered': 45.0,
#    'Recovery_Rate': 0.05244755244755245,
#    'Death_Rate': 0.01282051282051282},
#   0.10141206675224645),
#  'Netherlands': ({'Province': 'Sint Maarten',
#    'Date': '2020-04-02',
#    'Confirmed': 18.0,
#    'Deaths': 1.0,
#    'Recovered': 6.0,
#    'Recovery_Rate': 0.3333333333333333,
#    'Death_Rate': 0.05555555555555555},
#   0.6363636363636365),
#  'San Marino': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 245.0,
#    'Deaths': 30.0,
#    'Recovered': 21.0,
#    'Recovery_Rate': 0.08571428571428572,
#    'Death_Rate': 0.12244897959183673},
#   0.03813559322033888),
#  ' Azerbaijan': ({'Province': None,
#    'Date': '2020-02-28',
#    'Confirmed': 1.0,
#    'Deaths': 0.0,
#    'Recovered': 0.0,
#    'Recovery_Rate': 0.0,
#    'Death_Rate': 0.0},
#   -0.9959183673469387),
#  'Belarus': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 304.0,
#    'Deaths': 4.0,
#    'Recovered': 53.0,
#    'Recovery_Rate': 0.17434210526315788,
#    'Death_Rate': 0.013157894736842105},
#   0.8650306748466257),
#  'Iceland': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 1319.0,
#    'Deaths': 4.0,
#    'Recovered': 284.0,
#    'Recovery_Rate': 0.21531463229719486,
#    'Death_Rate': 0.003032600454890068},
#   0.08114754098360666),
#  'Lithuania': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 649.0,
#    'Deaths': 9.0,
#    'Recovered': 7.0,
#    'Recovery_Rate': 0.01078582434514638,
#    'Death_Rate': 0.01386748844375963},
#   0.11703958691910499),
#  'New Zealand': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 797.0,
#    'Deaths': 1.0,
#    'Recovered': 92.0,
#    'Recovery_Rate': 0.11543287327478043,
#    'Death_Rate': 0.0012547051442910915},
#   0.12570621468926557),
#  'Nigeria': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 184.0,
#    'Deaths': 2.0,
#    'Recovered': 20.0,
#    'Recovery_Rate': 0.10869565217391304,
#    'Death_Rate': 0.010869565217391304},
#   0.05747126436781613),
#  'North Ireland': ({'Province': None,
#    'Date': '2020-02-28',
#    'Confirmed': 1.0,
#    'Deaths': 0.0,
#    'Recovered': 0.0,
#    'Recovery_Rate': 0.0,
#    'Death_Rate': 0.0},
#   -0.9945652173913043),
#  'Ireland': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 3849.0,
#    'Deaths': 98.0,
#    'Recovered': 5.0,
#    'Recovery_Rate': 0.0012990387113535984,
#    'Death_Rate': 0.025461158742530528},
#   0.11662315056570938),
#  'Luxembourg': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 2487.0,
#    'Deaths': 30.0,
#    'Recovered': 80.0,
#    'Recovery_Rate': 0.03216726980297547,
#    'Death_Rate': 0.012062726176115802},
#   0.07244501940491599),
#  'Monaco': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 60.0,
#    'Deaths': 1.0,
#    'Recovered': 2.0,
#    'Recovery_Rate': 0.03333333333333333,
#    'Death_Rate': 0.016666666666666666},
#   0.09090909090909083),
#  'Qatar': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 949.0,
#    'Deaths': 3.0,
#    'Recovered': 72.0,
#    'Recovery_Rate': 0.07586933614330875,
#    'Death_Rate': 0.003161222339304531},
#   0.13652694610778449),
#  'Ecuador': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 3163.0,
#    'Deaths': 120.0,
#    'Recovered': 65.0,
#    'Recovery_Rate': 0.020550110654441987,
#    'Death_Rate': 0.0379386658235852},
#   0.1510189228529839),
#  'Azerbaijan': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 400.0,
#    'Deaths': 5.0,
#    'Recovered': 26.0,
#    'Recovery_Rate': 0.065,
#    'Death_Rate': 0.0125},
#   0.11420612813370479),
#  'Czech Republic': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 3858.0,
#    'Deaths': 44.0,
#    'Recovered': 67.0,
#    'Recovery_Rate': 0.017366511145671334,
#    'Death_Rate': 0.011404872991187144},
#   0.09977194982896243),
#  'Armenia': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 663.0,
#    'Deaths': 7.0,
#    'Recovered': 33.0,
#    'Recovery_Rate': 0.049773755656108594,
#    'Death_Rate': 0.010558069381598794},
#   0.16112084063047294),
#  'Dominican Republic': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 1380.0,
#    'Deaths': 60.0,
#    'Recovered': 16.0,
#    'Recovery_Rate': 0.011594202898550725,
#    'Death_Rate': 0.043478260869565216},
#   0.07476635514018692),
#  'Indonesia': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 1790.0,
#    'Deaths': 170.0,
#    'Recovered': 112.0,
#    'Recovery_Rate': 0.06256983240223464,
#    'Death_Rate': 0.09497206703910614},
#   0.06738223017292788),
#  'Portugal': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 9034.0,
#    'Deaths': 209.0,
#    'Recovered': 68.0,
#    'Recovery_Rate': 0.00752711976975869,
#    'Death_Rate': 0.02313482399822891},
#   0.0948975881711307),
#  'Andorra': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 428.0,
#    'Deaths': 15.0,
#    'Recovered': 10.0,
#    'Recovery_Rate': 0.02336448598130841,
#    'Death_Rate': 0.035046728971962614},
#   0.09743589743589753),
#  'Latvia': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 458.0,
#    'Deaths': 0.0,
#    'Recovered': 31.0,
#    'Recovery_Rate': 0.06768558951965066,
#    'Death_Rate': 0.0},
#   0.026905829596412634),
#  'Morocco': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 708.0,
#    'Deaths': 44.0,
#    'Recovered': 31.0,
#    'Recovery_Rate': 0.043785310734463276,
#    'Death_Rate': 0.062146892655367235},
#   0.08256880733944949),
#  'Saudi Arabia': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 1885.0,
#    'Deaths': 21.0,
#    'Recovered': 328.0,
#    'Recovery_Rate': 0.1740053050397878,
#    'Death_Rate': 0.011140583554376658},
#   0.09593023255813948),
#  'Senegal': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 195.0,
#    'Deaths': 1.0,
#    'Recovered': 55.0,
#    'Recovery_Rate': 0.28205128205128205,
#    'Death_Rate': 0.005128205128205128},
#   0.026315789473684292),
#  'Argentina': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 1133.0,
#    'Deaths': 36.0,
#    'Recovered': 256.0,
#    'Recovery_Rate': 0.22594880847308033,
#    'Death_Rate': 0.03177405119152692},
#   0.07495256166982922),
#  'Chile': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 3404.0,
#    'Deaths': 18.0,
#    'Recovered': 335.0,
#    'Recovery_Rate': 0.09841363102232667,
#    'Death_Rate': 0.005287896592244419},
#   0.12306169580996373),
#  'Jordan': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 299.0,
#    'Deaths': 5.0,
#    'Recovered': 45.0,
#    'Recovery_Rate': 0.1505016722408027,
#    'Death_Rate': 0.016722408026755852},
#   0.07553956834532372),
#  'Ukraine': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 897.0,
#    'Deaths': 22.0,
#    'Recovered': 19.0,
#    'Recovery_Rate': 0.021181716833890748,
#    'Death_Rate': 0.024526198439241916},
#   0.12972292191435764),
#  'Saint Barthelemy': ({'Province': None,
#    'Date': '2020-03-10',
#    'Confirmed': 1.0,
#    'Deaths': 0.0,
#    'Recovered': 0.0,
#    'Recovery_Rate': 0.0,
#    'Death_Rate': 0.0},
#   0.0),
#  'Hungary': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 585.0,
#    'Deaths': 21.0,
#    'Recovered': 42.0,
#    'Recovery_Rate': 0.07179487179487179,
#    'Death_Rate': 0.035897435897435895},
#   0.11428571428571432),
#  'Faroe Islands': ({'Province': None,
#    'Date': '2020-03-10',
#    'Confirmed': 2.0,
#    'Deaths': 0.0,
#    'Recovered': 0.0,
#    'Recovery_Rate': 0.0,
#    'Death_Rate': 0.0},
#   0.0),
#  'Gibraltar': ({'Province': None,
#    'Date': '2020-03-10',
#    'Confirmed': 1.0,
#    'Deaths': 0.0,
#    'Recovered': 1.0,
#    'Recovery_Rate': 1.0,
#    'Death_Rate': 0.0},
#   0.0),
#  'Liechtenstein': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 75.0,
#    'Deaths': 0.0,
#    'Recovered': 0.0,
#    'Recovery_Rate': 0.0,
#    'Death_Rate': 0.0},
#   0.10294117647058831),
#  'Poland': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 2946.0,
#    'Deaths': 57.0,
#    'Recovered': 56.0,
#    'Recovery_Rate': 0.019008825526137134,
#    'Death_Rate': 0.019348268839103868},
#   0.15348472983555217),
#  'Tunisia': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 455.0,
#    'Deaths': 14.0,
#    'Recovered': 5.0,
#    'Recovery_Rate': 0.01098901098901099,
#    'Death_Rate': 0.03076923076923077},
#   0.0756501182033098),
#  'Palestine': ({'Province': None,
#    'Date': '2020-03-09',
#    'Confirmed': 22.0,
#    'Deaths': 0.0,
#    'Recovered': 0.0,
#    'Recovery_Rate': 0.0,
#    'Death_Rate': 0.0},
#   0.0),
#  'Bosnia and Herzegovina': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 533.0,
#    'Deaths': 16.0,
#    'Recovered': 20.0,
#    'Recovery_Rate': 0.0375234521575985,
#    'Death_Rate': 0.0300187617260788},
#   0.1612200435729847),
#  'Slovenia': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 897.0,
#    'Deaths': 17.0,
#    'Recovered': 70.0,
#    'Recovery_Rate': 0.07803790412486064,
#    'Death_Rate': 0.0189520624303233},
#   0.06658739595719387),
#  'South Africa': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 1462.0,
#    'Deaths': 5.0,
#    'Recovered': 50.0,
#    'Recovery_Rate': 0.03419972640218878,
#    'Death_Rate': 0.003419972640218878},
#   0.05942028985507242),
#  'Bhutan': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 5.0,
#    'Deaths': 0.0,
#    'Recovered': 1.0,
#    'Recovery_Rate': 0.2,
#    'Death_Rate': 0.0},
#   0.25),
#  'Cameroon': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 306.0,
#    'Deaths': 7.0,
#    'Recovered': 10.0,
#    'Recovery_Rate': 0.032679738562091505,
#    'Death_Rate': 0.02287581699346405},
#   0.3133047210300428),
#  'Costa Rica': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 396.0,
#    'Deaths': 2.0,
#    'Recovered': 6.0,
#    'Recovery_Rate': 0.015151515151515152,
#    'Death_Rate': 0.005050505050505051},
#   0.05600000000000005),
#  'Peru': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 1414.0,
#    'Deaths': 55.0,
#    'Recovered': 537.0,
#    'Recovery_Rate': 0.3797736916548798,
#    'Death_Rate': 0.038896746817538894},
#   0.06878306878306883),
#  'Serbia': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 1171.0,
#    'Deaths': 31.0,
#    'Recovered': 0.0,
#    'Recovery_Rate': 0.0,
#    'Death_Rate': 0.026473099914602904},
#   0.10471698113207539),
#  'Slovakia': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 426.0,
#    'Deaths': 1.0,
#    'Recovered': 5.0,
#    'Recovery_Rate': 0.011737089201877934,
#    'Death_Rate': 0.002347417840375587},
#   0.06499999999999995),
#  'Togo': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 39.0,
#    'Deaths': 2.0,
#    'Recovered': 17.0,
#    'Recovery_Rate': 0.4358974358974359,
#    'Death_Rate': 0.05128205128205128},
#   0.08333333333333326),
#  'Vatican City': ({'Province': None,
#    'Date': '2020-03-09',
#    'Confirmed': 1.0,
#    'Deaths': 0.0,
#    'Recovered': 0.0,
#    'Recovery_Rate': 0.0,
#    'Death_Rate': 0.0},
#   0.0),
#  'French Guiana': ({'Province': None,
#    'Date': '2020-03-21',
#    'Confirmed': 18.0,
#    'Deaths': 0.0,
#    'Recovered': 6.0,
#    'Recovery_Rate': 0.3333333333333333,
#    'Death_Rate': 0.0},
#   0.19999999999999996),
#  'Malta': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 196.0,
#    'Deaths': 0.0,
#    'Recovered': 2.0,
#    'Recovery_Rate': 0.01020408163265306,
#    'Death_Rate': 0.0},
#   0.042553191489361764),
#  'Martinique': ({'Province': None,
#    'Date': '2020-03-21',
#    'Confirmed': 32.0,
#    'Deaths': 1.0,
#    'Recovered': 0.0,
#    'Recovery_Rate': 0.0,
#    'Death_Rate': 0.03125},
#   0.0),
#  'Bulgaria': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 457.0,
#    'Deaths': 10.0,
#    'Recovered': 25.0,
#    'Recovery_Rate': 0.05470459518599562,
#    'Death_Rate': 0.02188183807439825},
#   0.08293838862559233),
#  'Maldives': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 19.0,
#    'Deaths': 0.0,
#    'Recovered': 13.0,
#    'Recovery_Rate': 0.6842105263157895,
#    'Death_Rate': 0.0},
#   0.0),
#  'Bangladesh': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 56.0,
#    'Deaths': 6.0,
#    'Recovered': 25.0,
#    'Recovery_Rate': 0.44642857142857145,
#    'Death_Rate': 0.10714285714285714},
#   0.03703703703703698),
#  'Moldova': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 505.0,
#    'Deaths': 6.0,
#    'Recovered': 23.0,
#    'Recovery_Rate': 0.04554455445544554,
#    'Death_Rate': 0.011881188118811881},
#   0.19385342789598115),
#  'Paraguay': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 77.0,
#    'Deaths': 3.0,
#    'Recovered': 2.0,
#    'Recovery_Rate': 0.025974025974025976,
#    'Death_Rate': 0.03896103896103896},
#   0.11594202898550732),
#  'Albania': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 277.0,
#    'Deaths': 16.0,
#    'Recovered': 76.0,
#    'Recovery_Rate': 0.2743682310469314,
#    'Death_Rate': 0.05776173285198556},
#   0.06949806949806958),
#  'Cyprus': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 356.0,
#    'Deaths': 10.0,
#    'Recovered': 28.0,
#    'Recovery_Rate': 0.07865168539325842,
#    'Death_Rate': 0.028089887640449437},
#   0.11250000000000004),
#  'St. Martin': ({'Province': None,
#    'Date': '2020-03-10',
#    'Confirmed': 2.0,
#    'Deaths': 0.0,
#    'Recovered': 0.0,
#    'Recovery_Rate': 0.0,
#    'Death_Rate': 0.0},
#   0.0),
#  'Brunei': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 133.0,
#    'Deaths': 1.0,
#    'Recovered': 56.0,
#    'Recovery_Rate': 0.42105263157894735,
#    'Death_Rate': 0.007518796992481203},
#   0.01526717557251911),
#  'occupied Palestinian territory': ({'Province': None,
#    'Date': '2020-03-17',
#    'Confirmed': 0.0,
#    'Deaths': 0.0,
#    'Recovered': 0.0,
#    'Recovery_Rate': 0,
#    'Death_Rate': 0},
#   nan),
#  'Burkina Faso': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 288.0,
#    'Deaths': 16.0,
#    'Recovered': 50.0,
#    'Recovery_Rate': 0.1736111111111111,
#    'Death_Rate': 0.05555555555555555},
#   0.02127659574468077),
#  'Channel Islands': ({'Province': None,
#    'Date': '2020-03-10',
#    'Confirmed': 1.0,
#    'Deaths': 0.0,
#    'Recovered': 0.0,
#    'Recovery_Rate': 0.0,
#    'Death_Rate': 0.0},
#   -0.9965277777777778),
#  'Holy See': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 7.0,
#    'Deaths': 0.0,
#    'Recovered': 0.0,
#    'Recovery_Rate': 0.0,
#    'Death_Rate': 0.0},
#   0.16666666666666674),
#  'Mongolia': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 14.0,
#    'Deaths': 0.0,
#    'Recovered': 2.0,
#    'Recovery_Rate': 0.14285714285714285,
#    'Death_Rate': 0.0},
#   0.0),
#  'Panama': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 1317.0,
#    'Deaths': 32.0,
#    'Recovered': 9.0,
#    'Recovery_Rate': 0.00683371298405467,
#    'Death_Rate': 0.024297646165527716},
#   0.11515664690939875),
#  'Bolivia': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 123.0,
#    'Deaths': 8.0,
#    'Recovered': 1.0,
#    'Recovery_Rate': 0.008130081300813009,
#    'Death_Rate': 0.06504065040650407},
#   0.06956521739130439),
#  'Honduras': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 219.0,
#    'Deaths': 14.0,
#    'Recovered': 3.0,
#    'Recovery_Rate': 0.0136986301369863,
#    'Death_Rate': 0.0639269406392694},
#   0.2732558139534884),
#  'Congo (Kinshasa)': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 134.0,
#    'Deaths': 13.0,
#    'Recovered': 3.0,
#    'Recovery_Rate': 0.022388059701492536,
#    'Death_Rate': 0.09701492537313433},
#   0.22935779816513757),
#  'Jamaica': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 47.0,
#    'Deaths': 3.0,
#    'Recovered': 2.0,
#    'Recovery_Rate': 0.0425531914893617,
#    'Death_Rate': 0.06382978723404255},
#   0.06818181818181812),
#  'Reunion': ({'Province': None,
#    'Date': '2020-03-21',
#    'Confirmed': 45.0,
#    'Deaths': 0.0,
#    'Recovered': 0.0,
#    'Recovery_Rate': 0.0,
#    'Death_Rate': 0.0},
#   0.6071428571428572),
#  'Turkey': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 18135.0,
#    'Deaths': 356.0,
#    'Recovered': 415.0,
#    'Recovery_Rate': 0.022883926109732562,
#    'Death_Rate': 0.019630548662806727},
#   0.15664264302570308),
#  'Cuba': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 233.0,
#    'Deaths': 6.0,
#    'Recovered': 13.0,
#    'Recovery_Rate': 0.055793991416309016,
#    'Death_Rate': 0.02575107296137339},
#   0.09905660377358494),
#  'Guyana': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 19.0,
#    'Deaths': 4.0,
#    'Recovered': 0.0,
#    'Recovery_Rate': 0.0,
#    'Death_Rate': 0.21052631578947367},
#   0.0),
#  'Kazakhstan': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 435.0,
#    'Deaths': 3.0,
#    'Recovered': 27.0,
#    'Recovery_Rate': 0.06206896551724138,
#    'Death_Rate': 0.006896551724137931},
#   0.14473684210526305),
#  'Cayman Islands': ({'Province': None,
#    'Date': '2020-03-15',
#    'Confirmed': 1.0,
#    'Deaths': 0.0,
#    'Recovered': 0.0,
#    'Recovery_Rate': 0.0,
#    'Death_Rate': 0.0},
#   0.0),
#  'Guadeloupe': ({'Province': None,
#    'Date': '2020-03-21',
#    'Confirmed': 53.0,
#    'Deaths': 0.0,
#    'Recovered': 0.0,
#    'Recovery_Rate': 0.0,
#    'Death_Rate': 0.0},
#   0.1777777777777778),
#  'Ethiopia': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 29.0,
#    'Deaths': 0.0,
#    'Recovered': 3.0,
#    'Recovery_Rate': 0.10344827586206896,
#    'Death_Rate': 0.0},
#   0.0),
#  'Sudan': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 8.0,
#    'Deaths': 2.0,
#    'Recovered': 2.0,
#    'Recovery_Rate': 0.25,
#    'Death_Rate': 0.25},
#   0.1428571428571428),
#  'Guinea': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 52.0,
#    'Deaths': 0.0,
#    'Recovered': 0.0,
#    'Recovery_Rate': 0.0,
#    'Death_Rate': 0.0},
#   0.7333333333333334),
#  'Antigua and Barbuda': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 9.0,
#    'Deaths': 0.0,
#    'Recovered': 0.0,
#    'Recovery_Rate': 0.0,
#    'Death_Rate': 0.0},
#   0.2857142857142858),
#  'Aruba': ({'Province': None,
#    'Date': '2020-03-19',
#    'Confirmed': 4.0,
#    'Deaths': 0.0,
#    'Recovered': 0.0,
#    'Recovery_Rate': 0.0,
#    'Death_Rate': 0.0},
#   0.0),
#  'Kenya': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 110.0,
#    'Deaths': 3.0,
#    'Recovered': 4.0,
#    'Recovery_Rate': 0.03636363636363636,
#    'Death_Rate': 0.02727272727272727},
#   0.3580246913580247),
#  'Uruguay': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 350.0,
#    'Deaths': 4.0,
#    'Recovered': 62.0,
#    'Recovery_Rate': 0.17714285714285713,
#    'Death_Rate': 0.011428571428571429},
#   0.035502958579881616),
#  'Ghana': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 204.0,
#    'Deaths': 5.0,
#    'Recovered': 31.0,
#    'Recovery_Rate': 0.15196078431372548,
#    'Death_Rate': 0.024509803921568627},
#   0.04615384615384621),
#  'Jersey': ({'Province': None,
#    'Date': '2020-03-21',
#    'Confirmed': 0.0,
#    'Deaths': 0.0,
#    'Recovered': 0.0,
#    'Recovery_Rate': 0,
#    'Death_Rate': 0},
#   nan),
#  'Namibia': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 14.0,
#    'Deaths': 0.0,
#    'Recovered': 3.0,
#    'Recovery_Rate': 0.21428571428571427,
#    'Death_Rate': 0.0},
#   0.0),
#  'Seychelles': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 10.0,
#    'Deaths': 0.0,
#    'Recovered': 0.0,
#    'Recovery_Rate': 0.0,
#    'Death_Rate': 0.0},
#   0.0),
#  'Trinidad and Tobago': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 94.0,
#    'Deaths': 5.0,
#    'Recovered': 1.0,
#    'Recovery_Rate': 0.010638297872340425,
#    'Death_Rate': 0.05319148936170213},
#   0.04444444444444451),
#  'Venezuela': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 146.0,
#    'Deaths': 5.0,
#    'Recovered': 43.0,
#    'Recovery_Rate': 0.2945205479452055,
#    'Death_Rate': 0.03424657534246575},
#   0.020979020979021046),
#  'Curacao': ({'Province': None,
#    'Date': '2020-03-15',
#    'Confirmed': 1.0,
#    'Deaths': 0.0,
#    'Recovered': 0.0,
#    'Recovery_Rate': 0.0,
#    'Death_Rate': 0.0},
#   0.0),
#  'Eswatini': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 9.0,
#    'Deaths': 0.0,
#    'Recovered': 0.0,
#    'Recovery_Rate': 0.0,
#    'Death_Rate': 0.0},
#   0.0),
#  'Gabon': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 21.0,
#    'Deaths': 1.0,
#    'Recovered': 0.0,
#    'Recovery_Rate': 0.0,
#    'Death_Rate': 0.047619047619047616},
#   0.16666666666666674),
#  'Guatemala': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 47.0,
#    'Deaths': 1.0,
#    'Recovered': 12.0,
#    'Recovery_Rate': 0.2553191489361702,
#    'Death_Rate': 0.02127659574468085},
#   0.20512820512820507),
#  'Guernsey': ({'Province': None,
#    'Date': '2020-03-21',
#    'Confirmed': 0.0,
#    'Deaths': 0.0,
#    'Recovered': 0.0,
#    'Recovery_Rate': 0,
#    'Death_Rate': 0},
#   nan),
#  'Mauritania': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 6.0,
#    'Deaths': 1.0,
#    'Recovered': 2.0,
#    'Recovery_Rate': 0.3333333333333333,
#    'Death_Rate': 0.16666666666666666},
#   0.0),
#  'Rwanda': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 84.0,
#    'Deaths': 0.0,
#    'Recovered': 0.0,
#    'Recovery_Rate': 0.0,
#    'Death_Rate': 0.0},
#   0.024390243902439046),
#  'Saint Lucia': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 13.0,
#    'Deaths': 0.0,
#    'Recovered': 1.0,
#    'Recovery_Rate': 0.07692307692307693,
#    'Death_Rate': 0.0},
#   0.0),
#  'Saint Vincent and the Grenadines': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 2.0,
#    'Deaths': 0.0,
#    'Recovered': 1.0,
#    'Recovery_Rate': 0.5,
#    'Death_Rate': 0.0},
#   1.0),
#  'Suriname': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 10.0,
#    'Deaths': 0.0,
#    'Recovered': 0.0,
#    'Recovery_Rate': 0.0,
#    'Death_Rate': 0.0},
#   0.0),
#  'Kosovo': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 125.0,
#    'Deaths': 1.0,
#    'Recovered': 10.0,
#    'Recovery_Rate': 0.08,
#    'Death_Rate': 0.008},
#   0.0),
#  'Central African Republic': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 3.0,
#    'Deaths': 0.0,
#    'Recovered': 0.0,
#    'Recovery_Rate': 0.0,
#    'Death_Rate': 0.0},
#   0.0),
#  'Congo (Brazzaville)': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 22.0,
#    'Deaths': 2.0,
#    'Recovered': 2.0,
#    'Recovery_Rate': 0.09090909090909091,
#    'Death_Rate': 0.09090909090909091},
#   0.1578947368421053),
#  'Equatorial Guinea': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 15.0,
#    'Deaths': 0.0,
#    'Recovered': 1.0,
#    'Recovery_Rate': 0.06666666666666667,
#    'Death_Rate': 0.0},
#   0.0),
#  'Uzbekistan': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 205.0,
#    'Deaths': 2.0,
#    'Recovered': 25.0,
#    'Recovery_Rate': 0.12195121951219512,
#    'Death_Rate': 0.00975609756097561},
#   0.13259668508287303),
#  'Guam': ({'Province': None,
#    'Date': '2020-03-21',
#    'Confirmed': 0.0,
#    'Deaths': 0.0,
#    'Recovered': 0.0,
#    'Recovery_Rate': 0,
#    'Death_Rate': 0},
#   nan),
#  'Puerto Rico': ({'Province': None,
#    'Date': '2020-03-21',
#    'Confirmed': 0.0,
#    'Deaths': 0.0,
#    'Recovered': 0.0,
#    'Recovery_Rate': 0,
#    'Death_Rate': 0},
#   nan),
#  'Benin': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 13.0,
#    'Deaths': 0.0,
#    'Recovered': 1.0,
#    'Recovery_Rate': 0.07692307692307693,
#    'Death_Rate': 0.0},
#   0.0),
#  'Greenland': ({'Province': None,
#    'Date': '2020-03-21',
#    'Confirmed': 0.0,
#    'Deaths': 0.0,
#    'Recovered': 0.0,
#    'Recovery_Rate': 0,
#    'Death_Rate': 0},
#   nan),
#  'Liberia': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 6.0,
#    'Deaths': 0.0,
#    'Recovered': 0.0,
#    'Recovery_Rate': 0.0,
#    'Death_Rate': 0.0},
#   0.0),
#  'Mayotte': ({'Province': None,
#    'Date': '2020-03-21',
#    'Confirmed': 7.0,
#    'Deaths': 0.0,
#    'Recovered': 0.0,
#    'Recovery_Rate': 0.0,
#    'Death_Rate': 0.0},
#   0.16666666666666674),
#  'Republic of the Congo': ({'Province': None,
#    'Date': '2020-03-21',
#    'Confirmed': 0.0,
#    'Deaths': 0.0,
#    'Recovered': 0.0,
#    'Recovery_Rate': 0,
#    'Death_Rate': 0},
#   nan),
#  'Somalia': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 5.0,
#    'Deaths': 0.0,
#    'Recovered': 1.0,
#    'Recovery_Rate': 0.2,
#    'Death_Rate': 0.0},
#   0.0),
#  'Tanzania': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 20.0,
#    'Deaths': 1.0,
#    'Recovered': 2.0,
#    'Recovery_Rate': 0.1,
#    'Death_Rate': 0.05},
#   0.0),
#  'The Bahamas': ({'Province': None,
#    'Date': '2020-03-21',
#    'Confirmed': 0.0,
#    'Deaths': 0.0,
#    'Recovered': 0.0,
#    'Recovery_Rate': 0,
#    'Death_Rate': 0},
#   nan),
#  'Barbados': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 46.0,
#    'Deaths': 0.0,
#    'Recovered': 0.0,
#    'Recovery_Rate': 0.0,
#    'Death_Rate': 0.0},
#   0.3529411764705883),
#  'Montenegro': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 144.0,
#    'Deaths': 2.0,
#    'Recovered': 0.0,
#    'Recovery_Rate': 0.0,
#    'Death_Rate': 0.013888888888888888},
#   0.1707317073170731),
#  'The Gambia': ({'Province': None,
#    'Date': '2020-03-21',
#    'Confirmed': 0.0,
#    'Deaths': 0.0,
#    'Recovered': 0.0,
#    'Recovery_Rate': 0,
#    'Death_Rate': 0},
#   nan),
#  'Kyrgyzstan': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 116.0,
#    'Deaths': 0.0,
#    'Recovered': 5.0,
#    'Recovery_Rate': 0.04310344827586207,
#    'Death_Rate': 0.0},
#   0.04504504504504503),
#  'Mauritius': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 169.0,
#    'Deaths': 7.0,
#    'Recovered': 0.0,
#    'Recovery_Rate': 0.0,
#    'Death_Rate': 0.04142011834319527},
#   0.049689440993788914),
#  'Zambia': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 39.0,
#    'Deaths': 1.0,
#    'Recovered': 0.0,
#    'Recovery_Rate': 0.0,
#    'Death_Rate': 0.02564102564102564},
#   0.08333333333333326),
#  'Djibouti': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 40.0,
#    'Deaths': 0.0,
#    'Recovered': 0.0,
#    'Recovery_Rate': 0.0,
#    'Death_Rate': 0.0},
#   0.21212121212121215),
#  'Gambia, The': ({'Province': None,
#    'Date': '2020-03-21',
#    'Confirmed': 1.0,
#    'Deaths': 0.0,
#    'Recovered': 0.0,
#    'Recovery_Rate': 0.0,
#    'Death_Rate': 0.0},
#   0.0),
#  'Bahamas, The': ({'Province': None,
#    'Date': '2020-03-21',
#    'Confirmed': 4.0,
#    'Deaths': 0.0,
#    'Recovered': 0.0,
#    'Recovery_Rate': 0.0,
#    'Death_Rate': 0.0},
#   0.33333333333333326),
#  'Chad': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 8.0,
#    'Deaths': 0.0,
#    'Recovered': 0.0,
#    'Recovery_Rate': 0.0,
#    'Death_Rate': 0.0},
#   0.1428571428571428),
#  'El Salvador': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 41.0,
#    'Deaths': 2.0,
#    'Recovered': 0.0,
#    'Recovery_Rate': 0.0,
#    'Death_Rate': 0.04878048780487805},
#   0.28125),
#  'Fiji': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 7.0,
#    'Deaths': 0.0,
#    'Recovered': 0.0,
#    'Recovery_Rate': 0.0,
#    'Death_Rate': 0.0},
#   0.3999999999999999),
#  'Nicaragua': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 5.0,
#    'Deaths': 1.0,
#    'Recovered': 0.0,
#    'Recovery_Rate': 0.0,
#    'Death_Rate': 0.2},
#   0.0),
#  'Madagascar': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 59.0,
#    'Deaths': 0.0,
#    'Recovered': 0.0,
#    'Recovery_Rate': 0.0,
#    'Death_Rate': 0.0},
#   0.03508771929824572),
#  'Haiti': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 16.0,
#    'Deaths': 0.0,
#    'Recovered': 1.0,
#    'Recovery_Rate': 0.0625,
#    'Death_Rate': 0.0},
#   0.0),
#  'Angola': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 8.0,
#    'Deaths': 2.0,
#    'Recovered': 1.0,
#    'Recovery_Rate': 0.125,
#    'Death_Rate': 0.25},
#   0.0),
#  'Cape Verde': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 6.0,
#    'Deaths': 1.0,
#    'Recovered': 0.0,
#    'Recovery_Rate': 0.0,
#    'Death_Rate': 0.16666666666666666},
#   0.0),
#  'Niger': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 98.0,
#    'Deaths': 5.0,
#    'Recovered': 0.0,
#    'Recovery_Rate': 0.0,
#    'Death_Rate': 0.05102040816326531},
#   0.32432432432432434),
#  'Papua New Guinea': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 1.0,
#    'Deaths': 0.0,
#    'Recovered': 0.0,
#    'Recovery_Rate': 0.0,
#    'Death_Rate': 0.0},
#   0.0),
#  'Zimbabwe': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 9.0,
#    'Deaths': 1.0,
#    'Recovered': 0.0,
#    'Recovery_Rate': 0.0,
#    'Death_Rate': 0.1111111111111111},
#   0.125),
#  'East Timor': ({'Province': None,
#    'Date': '2020-03-21',
#    'Confirmed': 1.0,
#    'Deaths': 0.0,
#    'Recovered': 0.0,
#    'Recovery_Rate': 0.0,
#    'Death_Rate': 0.0},
#   -0.8888888888888888),
#  'Eritrea': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 22.0,
#    'Deaths': 0.0,
#    'Recovered': 0.0,
#    'Recovery_Rate': 0.0,
#    'Death_Rate': 0.0},
#   0.46666666666666656),
#  'Uganda': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 45.0,
#    'Deaths': 0.0,
#    'Recovered': 0.0,
#    'Recovery_Rate': 0.0,
#    'Death_Rate': 0.0},
#   0.022727272727272707),
#  'Bahamas': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 24.0,
#    'Deaths': 1.0,
#    'Recovered': 1.0,
#    'Recovery_Rate': 0.041666666666666664,
#    'Death_Rate': 0.041666666666666664},
#   0.1428571428571428),
#  'Dominica': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 12.0,
#    'Deaths': 0.0,
#    'Recovered': 0.0,
#    'Recovery_Rate': 0.0,
#    'Death_Rate': 0.0},
#   0.0),
#  'Gambia': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 4.0,
#    'Deaths': 1.0,
#    'Recovered': 2.0,
#    'Recovery_Rate': 0.5,
#    'Death_Rate': 0.25},
#   0.0),
#  'Grenada': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 10.0,
#    'Deaths': 0.0,
#    'Recovered': 0.0,
#    'Recovery_Rate': 0.0,
#    'Death_Rate': 0.0},
#   0.11111111111111116),
#  'Mozambique': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 10.0,
#    'Deaths': 0.0,
#    'Recovered': 0.0,
#    'Recovery_Rate': 0.0,
#    'Death_Rate': 0.0},
#   0.0),
#  'Syria': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 16.0,
#    'Deaths': 2.0,
#    'Recovered': 0.0,
#    'Recovery_Rate': 0.0,
#    'Death_Rate': 0.125},
#   0.6000000000000001),
#  'Timor-Leste': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 1.0,
#    'Deaths': 0.0,
#    'Recovered': 0.0,
#    'Recovery_Rate': 0.0,
#    'Death_Rate': 0.0},
#   0.0),
#  'Belize': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 3.0,
#    'Deaths': 0.0,
#    'Recovered': 0.0,
#    'Recovery_Rate': 0.0,
#    'Death_Rate': 0.0},
#   0.0),
#  'Laos': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 10.0,
#    'Deaths': 0.0,
#    'Recovered': 0.0,
#    'Recovery_Rate': 0.0,
#    'Death_Rate': 0.0},
#   0.0),
#  'Libya': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 11.0,
#    'Deaths': 1.0,
#    'Recovered': 0.0,
#    'Recovery_Rate': 0.0,
#    'Death_Rate': 0.09090909090909091},
#   0.10000000000000009),
#  'Diamond Princess': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 712.0,
#    'Deaths': 11.0,
#    'Recovered': 619.0,
#    'Recovery_Rate': 0.8693820224719101,
#    'Death_Rate': 0.01544943820224719},
#   0.0),
#  'Guinea-Bissau': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 9.0,
#    'Deaths': 0.0,
#    'Recovered': 0.0,
#    'Recovery_Rate': 0.0,
#    'Death_Rate': 0.0},
#   0.0),
#  'Mali': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 36.0,
#    'Deaths': 3.0,
#    'Recovered': 0.0,
#    'Recovery_Rate': 0.0,
#    'Death_Rate': 0.08333333333333333},
#   0.16129032258064524),
#  'Saint Kitts and Nevis': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 9.0,
#    'Deaths': 0.0,
#    'Recovered': 0.0,
#    'Recovery_Rate': 0.0,
#    'Death_Rate': 0.0},
#   0.125),
#  'West Bank and Gaza': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 161.0,
#    'Deaths': 1.0,
#    'Recovered': 18.0,
#    'Recovery_Rate': 0.11180124223602485,
#    'Death_Rate': 0.006211180124223602},
#   0.20149253731343286),
#  'Burma': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 20.0,
#    'Deaths': 1.0,
#    'Recovered': 0.0,
#    'Recovery_Rate': 0.0,
#    'Death_Rate': 0.05},
#   0.33333333333333326),
#  'MS Zaandam': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 9.0,
#    'Deaths': 2.0,
#    'Recovered': 0.0,
#    'Recovery_Rate': 0.0,
#    'Death_Rate': 0.2222222222222222},
#   0.0),
#  'Botswana': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 4.0,
#    'Deaths': 1.0,
#    'Recovered': 0.0,
#    'Recovery_Rate': 0.0,
#    'Death_Rate': 0.25},
#   0.0),
#  'Burundi': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 3.0,
#    'Deaths': 0.0,
#    'Recovered': 0.0,
#    'Recovery_Rate': 0.0,
#    'Death_Rate': 0.0},
#   0.5),
#  'Sierra Leone': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 2.0,
#    'Deaths': 0.0,
#    'Recovered': 0.0,
#    'Recovery_Rate': 0.0,
#    'Death_Rate': 0.0},
#   0.0),
#  'Malawi': ({'Province': None,
#    'Date': '2020-04-02',
#    'Confirmed': 3.0,
#    'Deaths': 0.0,
#    'Recovered': 0.0,
#    'Recovery_Rate': 0.0,
#    'Death_Rate': 0.0},
#   0.5)}

# %%
len(confirmed_percent_change)
# Out:
# 11299

# %%
l1 = []
l2 = []
l3 = []
l4 = []

my_dict = {
    "key1": {
        "key11": l1,
        "key12": l2
    },
    "key2": {
        "key21": l3,
        "key22": l4
    }
}

# %%
my_dict["key1"]["key12"].append("a")

# %%
my_dict["key2"]["key24"]["key241"] = []
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-b4fc64c90984> in <module>
# ----> 1 my_dict["key2"]["key24"]["key241"] = []
#
# KeyError: 'key24'

# %%
my_dict["key3"] = {}

# %%
my_dict
# Out:
# {'key1': {'key11': [], 'key12': ['a', 'a']},
#  'key2': {'key21': [], 'key22': [], 'key23': []},
#  'key3': {}}

# %%
mock_covid_dict = {
    "country_without_provinces1": {
        "Confirmed": [1, 2, 4, 8],
        "Date": ["2020-04-02", "2020-04-03", "2020-04-04", "2020-04-05"],
        "Death_Rate": 0.02,
        "Deaths": [0, 1, 2, 5],
        "Recovered": [0, 0, 1, 2],
        "Recovery_Rate": 0.03
    },
    "country_without_provinces2": {
        "Confirmed": [11, 21, 41, 82],
        "Date": ["2020-04-02", "2020-04-03", "2020-04-04", "2020-04-05"],
        "Death_Rate": 0.02,
        "Deaths": [0, 1, 2, 5],
        "Recovered": [0, 0, 1, 2],
        "Recovery_Rate": 0.03
    },
    "country_WITH_provinces1": {
        "province_A":{
            "Confirmed": [1, 2, 4, 8],
            "Date": ["2020-04-02", "2020-04-03", "2020-04-04", "2020-04-05"],
            "Death_Rate": 0.02,
            "Deaths": [0, 1, 2, 5],
            "Recovered": [0, 0, 1, 2],
            "Recovery_Rate": 0.03
        },
        "province_B":{
            "Confirmed": [1, 2, 4, 8],
            "Date": ["2020-04-02", "2020-04-03", "2020-04-04", "2020-04-05"],
            "Death_Rate": 0.02,
            "Deaths": [0, 1, 2, 5],
            "Recovered": [0, 0, 1, 2],
            "Recovery_Rate": 0.03
        }
    },
    "country_WITH_provinces2": {
        "province_C":{
            "Confirmed": [1, 2, 4, 8],
            "Date": ["2020-04-02", "2020-04-03", "2020-04-04", "2020-04-05"],
            "Death_Rate": 0.02,
            "Deaths": [0, 1, 2, 5],
            "Recovered": [0, 0, 1, 2],
            "Recovery_Rate": 0.03
        },
        "province_D":{
            "Confirmed": [1, 2, 4, 8],
            "Date": ["2020-04-02", "2020-04-03", "2020-04-04", "2020-04-05"],
            "Death_Rate": 0.02,
            "Deaths": [0, 1, 2, 5],
            "Recovered": [0, 0, 1, 2],
            "Recovery_Rate": 0.03
        }
    }
}
